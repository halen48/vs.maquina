# %%
import mido

mid = mido.MidiFile('musica.mid')

for track in mid.tracks:
    for msg in track:
        if msg.type == 'program_change' and msg.channel == 3:
            msg.program = 127

mid.save('musica_2.mid')
# !timidity musica_2.mid
# Out:
# Playing musica_2.mid
# MIDI file: musica_2.mid
# Format: 0  Tracks: 1  Divisions: 480
# Playing time: ~52 secondse every night ohit that sweet? I guess so you can't sleep baby I knowthat me espresso it up down left right ohit up like Nintendo can't sleep baby I knowthat me espresso I can't relate to desperation'give a fucks' are on vacationI got this one boyhe won't stop callingthey act this wayknow I got 'em
# Notes cut: 0
# Notes lost totally: 0
